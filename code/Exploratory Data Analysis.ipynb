# %%
import pyodbc
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
plt.rcParams.update({'font.size':10})
import dash
from dash import html
from dash import dcc
import plotly.graph_objects as go
import plotly.express as px
import dash_bootstrap_components as dbc
from dash import *
from dash.dependencies import Input, Output

# %%
#np.arange(0,1,1/50)

# %%
slider_range = np.unique(np.arange(0,30))
slider_range1 = np.unique(np.arange(0.0,1.1))

# %%
df = pd.read_csv(r"D:\dataset\ABB-Test\ABB-raw-update.csv")
# Out:
# C:\Users\91883\AppData\Local\Temp\ipykernel_69704\4016273915.py:1: DtypeWarning: Columns (13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\dataset\ABB-Test\ABB-raw-update.csv")

# %%
df = df.sort_values(['year','months','days'],ascending=[True,True,True])

# %%
#df.head()

# %%
#df[df.ASSEMBLY_ID.duplicated()==False].shape

# %%
df = df[df.ASSEMBLY_ID.duplicated()==False]
#df.shape

# %%
unique_feature = np.unique(df[(df.MECHANICAL_STICKER_STATUS==1)].PRODUCTION_PLAN_CUSTOMER.value_counts().index)
#len(unique_feature)

# %%
app = dash.Dash(__name__,external_stylesheets=[dbc.themes.FLATLY])

# -------------------------------------------------------------------------------------------------------------------------------
app.title = 'EDA-Dashboard v1'

#server = app.server
app.layout = html.Div(id='parent', children=[dbc.Container([
    

#--------------------------------------------------start-----------------------------------------------------------------------#    
dbc.Tabs([
        dbc.Tab(dbc.Card(
        dbc.CardBody([
# ------------------------------------------------------------------------------------------------------------------------------            
dbc.Row([
# row1 start
# ------------------------------------------------------------------------------------------------------------------------------
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([            
            
                                html.H4('Defect Analysis',style={'align': 'center'}),
                    ]),
color="primary", inverse=True))
#--------------------------------------------     
# row1 end
    ], className="g-0"),
# ------------------------------------------------------------------------------------------------------------------------------            
dbc.Row([
# row1 start
# ------------------------------------------------------------------------------------------------------------------------------
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([

                    dcc.Graph(id='pie-chart', style={'width': '100%', 'display': 'inline-block'}),

#----------------------------------------------- #['Defect Resolved','Defect Not Resolved']    
                        
                html.Div(id='col-0', children=[dcc.Dropdown(id='col0',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['Defect ID Distribution'],['Average Time'])],
                                                            value='Defect ID Distribution',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '100%', 'display': 'inline-block'}),
                ]),
#--------------------------------------------                
               ),# color="light"

            width=4),
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                dcc.Graph(id='pie-chart1', style={'width': '100%', 'display': 'inline-block'}),                        
                html.Div(id='col-1', children=[dcc.Dropdown(id='col1',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['Defect Resolved'],['Average Time'])],
                                                            value='Defect Resolved',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '100%', 'display': 'inline-block'}),                   
                ]),
#--------------------------------------------                
               ),# color="light"

            width=4),
    
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='pie-chart2', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-2', children=[dcc.Dropdown(id='col2',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['Defect Not Resolved'],['Average Time'])],
                                                            value='Defect Not Resolved',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '100%', 'display': 'inline-block'}),                   # dcc.Graph(id='pie-chart', style={'width': '100%', 'display': 'inline-block'}),

                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=4),
#--------------------------------------------     
# row1 end
    ], className="g-0"),

# ------------------------------------------------------------------------------------------------------------------------------            
dbc.Row([
# row1 start
# ------------------------------------------------------------------------------------------------------------------------------
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-3', children=[dcc.Dropdown(id='col3',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['All'],['2020','2021','2022'])],
                                                            value='All',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '100%', 'display': 'inline-block'}), 

                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=4), 
# ------------------------------------------------------------------------------------------------------------------------------
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot1', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-4', children=[dcc.Dropdown(id='col4',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['All'],['2020','2021','2022'])],
                                                            value='All',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '100%', 'display': 'inline-block'}), 

                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=4),   
# ------------------------------------------------------------------------------------------------------------------------------
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot2', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-5', children=[dcc.Dropdown(id='col5',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['All'],['2020','2021','2022'])],
                                                            value='All',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '100%', 'display': 'inline-block'}), 

                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=4),
#--------------------------------------------     
# row1 end
    ], className="g-0"),
            
# ------------------------------------------------------------------------------------------------------------------------------            
dbc.Row([
# row1 start            
            
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot3', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-6', children=[dcc.Dropdown(id='col6',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                           ['Offline Station'], [ 'FAT 2B Station', 'FAT Station',
                                                           'Offline Station', 'WP1 Spout Assembly', 'Z1 Structure Assembly',
                                                           'Z10 Panel Unloading', 'Z2 Structure Finishing', 'Z3 CT Mounting',
                                                           'Z4 Copper Assembly', 'Z5 Metering Box Assembly','FAT 2A Station',
                                                           'Z6 Rear Side Assembly', 'Z7 Front Wiring',
                                                           'Z8 Door Assembly & Wiring', 'Z9 Breaker Insertion & Inspection'])],
                                                            value='Offline Station',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '100%', 'display': 'inline-block'}), 

                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=4),            
            
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot4', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-7', children=[dcc.Dropdown(id='col7',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                           ['Offline Station'], [ 'FAT 2B Station', 'FAT Station',
                                                           'Offline Station', 'WP1 Spout Assembly', 'Z1 Structure Assembly',
                                                           'Z10 Panel Unloading', 'Z2 Structure Finishing', 'Z3 CT Mounting',
                                                           'Z4 Copper Assembly', 'Z5 Metering Box Assembly','FAT 2A Station',
                                                           'Z6 Rear Side Assembly', 'Z7 Front Wiring',
                                                           'Z8 Door Assembly & Wiring', 'Z9 Breaker Insertion & Inspection'])],
                                                            value='Offline Station',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '35%', 'display': 'inline-block'}), 

                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=8),                             
#--------------------------------------------     
# row1 end
    ], className="g-0"),            

            
dbc.Row([
# row1 start
# ------------------------------------------------------------------------------------------------------------------------------
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([            
            
                                html.H4('Operator Performance Analysis',style={'align': 'center'}),
                    ]),
color="primary", inverse=True))
#--------------------------------------------     
# row1 end
    ], className="g-0"),
# ------------------------------------------------------------------------------------------------------------------------------            
dbc.Row([
# row1 start  
    
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot5', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-8', children=[dcc.Dropdown(id='col8',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                           ['Offline Station'], [ 'FAT 2B Station', 'FAT Station',
                                                           'Offline Station', 'WP1 Spout Assembly', 'Z1 Structure Assembly',
                                                           'Z10 Panel Unloading', 'Z2 Structure Finishing', 'Z3 CT Mounting',
                                                           'Z4 Copper Assembly', 'Z5 Metering Box Assembly','FAT 2A Station',
                                                           'Z6 Rear Side Assembly', 'Z7 Front Wiring',
                                                           'Z8 Door Assembly & Wiring', 'Z9 Breaker Insertion & Inspection'])],
                                                            value='Offline Station',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '70%', 'display': 'inline-block'}), 
                        
                html.Div(id='col-9', children=[dcc.Dropdown(id='col9',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                           ['Avg_Time'], [ 'Count'])],
                                                            value='Avg_Time',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '30%', 'display': 'inline-block'}), 
                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=4),     
    
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot6', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-10', children=[dcc.Dropdown(id='col10',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['Expert'], ['Learner', 'Practitioner', 'Skilled', 'Untrained'])],
                                                            value='Expert',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '30%', 'display': 'inline-block'}), 
                        
                html.Div(id='col-11', children=[dcc.Dropdown(id='col11',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                           ['Avg_Time'], ['Count'])],
                                                            value='Avg_Time',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '30%', 'display': 'inline-block'}), 
                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=5),       
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot7', style={'width': '100%', 'display': 'inline-block'}),
                html.Div(id='col-12', children=[dcc.Dropdown(id='col12',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['All'], ['2020', '2021', '2022'])],
                                                            value='All',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '40%', 'display': 'inline-block'}), 
                        
                html.Div(id='col-13', children=[dcc.Dropdown(id='col13',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                           ['Avg_Time'], ['Count'])],
                                                            value='Avg_Time',
                                                            placeholder='Mode of Analysis',
                                                            clearable=True,
                                                            )],
                         style={'width': '60%', 'display': 'inline-block'}), 
                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=3),       
#--------------------------------------------  
    
# row1 end
    ], className="g-0"), 
dbc.Row([
# row1 start
# ------------------------------------------------------------------------------------------------------------------------------
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([            
            
                                html.H4('Production Analysis',style={'align': 'center'}),
                    ]),
color="primary", inverse=True))
#--------------------------------------------     
# row1 end
    ], className="g-0"),
# ------------------------------------------------------------------------------------------------------------------------------            
dbc.Row([
# row1 start  
# col1 start
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot8', style={'width': '100%', 'display': 'inline-block'}),
#-----------------------------------------------                        
                html.Div(id='col-14', children=[dcc.Dropdown(id='col14',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            [unique_feature[4]], unique_feature)],
                                                            value=unique_feature[4],
                                                            placeholder='Select Year',
                                                            clearable=True,
                                                            )],
                         style={'width': '82%', 'display': 'inline-block'}),
                html.Div(id='col-15', children=[dcc.Dropdown(id='col15',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['mean'], 'median')],
                                                            value='mean',
                                                            placeholder='Select Year',
                                                            clearable=True,
                                                            )],
                         style={'width': '18%', 'display': 'inline-block'}),
                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=7),        
    
        dbc.Col(
            dbc.Card(

                dbc.CardBody
                    ([
                        
                dcc.Graph(id='bar-plot9', style={'width': '100%', 'display': 'inline-block'}),
#-----------------------------------------------                        
                html.Div(id='col-16', children=[dcc.Dropdown(id='col16',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            [unique_feature[4]], unique_feature)],
                                                            value=unique_feature[4],
                                                            placeholder='Select Year',
                                                            clearable=True,
                                                            )],
                         style={'width': '80%', 'display': 'inline-block'}),
                html.Div(id='col-17', children=[dcc.Dropdown(id='col17',
                                                            options=[{'label': i, 'value': i} for i in np.append(
                                                            ['mean'], 'median')],
                                                            value='mean',
                                                            placeholder='Select Year',
                                                            clearable=True,
                                                            )],
                         style={'width': '20%', 'display': 'inline-block'}),
                ]),
 
#--------------------------------------------                
               ),# color="light"

            width=5),        
#--------------------------------------------     
# row1 end
    ], className="g-0"),             
]),
#--------------------------------------------            
    className="mt-3",),
    label="Descriptive Analysis"),
#----------------------------------------------3nd Tab window------------------------------------------------------------------#
# dbc.Tab(dbc.Card(
#         dbc.CardBody([
# #------------------------------------------------------------------------------------------------------------------------------#
      
# #------------------------------------------------------------------------------------------------------------------------------#          
#         ]),
#     className="mt-3",),
#     label="Analysis-3"),    
    
# #----------------------------------------------4nd Tab window------------------------------------------------------------------#
# dbc.Tab(dbc.Card(
#         dbc.CardBody([
# #------------------------------------------------------------------------------------------------------------------------------#               
# ]),
#     className="mt-3",),
#     label="Analysis-4"),      
#-------------------------------------------- 
])
#--------------------------------------End-------------------------------------------------------------------------------------#    
],fluid=True),
                                            
])


@app.callback(Output(component_id='pie-chart', component_property='figure'),
              [Input(component_id='col0', component_property='value')])

def pie_chart0(col0):

    if col0=='Defect ID Distribution':
        list1,list2 =[],[]
        new = [(list1.append('{}'.format(i)),list2.append(j)) for i,j in zip( df.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                       df.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]
        defect_id_table = pd.DataFrame({"defect_id":list1,"freq_count":list2})
        defect_id_table['Avg_Time'] = (df.groupby(['DEFECT_ID']).minutes.sum().values/df.groupby(['DEFECT_ID']).DEFECT_ID.count().values)
        dataset = defect_id_table.copy()
        fig = go.Figure(data=[go.Pie(labels=dataset.defect_id, values=dataset['freq_count'], hole=.3)]) 
        
    if col0=='Average Time':
        list1,list2 =[],[]
        new = [(list1.append('{}'.format(i)),list2.append(j)) for i,j in zip( df.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                       df.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]
        defect_id_table = pd.DataFrame({"defect_id":list1,"freq_count":list2})
        defect_id_table['Avg_Time'] = (df.groupby(['DEFECT_ID']).minutes.sum().values/df.groupby(['DEFECT_ID']).DEFECT_ID.count().values)
        dataset = defect_id_table.copy()
        
        fig = go.Figure(data=[go.Pie(labels=dataset.defect_id, values=dataset['Avg_Time'], hole=.3)])
            
    fig.update_traces(textposition='inside', textinfo='percent+label')
    
    fig.update_layout(
               title_text="Defect Id Frequency Distribution",
               showlegend=False,
               margin=dict(l=5, r=5, b=5, t=35, pad=2),

             # Add annotations in the center of the donut pies.
             annotations=[dict(text='Defect ID', x=0.5, y=0.5, font_size=12, showarrow=False)])
       
    return fig

@app.callback(Output(component_id='pie-chart1', component_property='figure'),
              [Input(component_id='col1', component_property='value')])

def pie_chart1(col0):

    if col0=='Defect Resolved':
        list1,list2 =[],[]
        dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==1]
        new = [(list1.append('{}'.format(i)),list2.append(j)) for i,j in zip(dy.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                        dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]
        defect_id_table = pd.DataFrame({"defect_id":list1,"freq_count":list2})
        defect_id_table['Avg_Time'] = (dy.groupby(['DEFECT_ID']).minutes.sum().values/dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)
        dataset = defect_id_table.copy()
        fig = go.Figure(data=[go.Pie(labels=dataset.defect_id, values=dataset['freq_count'], hole=.3)]) 
        
    if col0=='Average Time':
        list1,list2 =[],[]
        dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==1]
        new = [(list1.append('{}'.format(i)),list2.append(j)) for i,j in zip(dy.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                        dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]
        defect_id_table = pd.DataFrame({"defect_id":list1,"freq_count":list2})
        defect_id_table['Avg_Time'] = (dy.groupby(['DEFECT_ID']).minutes.sum().values/dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)
        dataset = defect_id_table.copy()
        
        fig = go.Figure(data=[go.Pie(labels=dataset.defect_id, values=dataset['Avg_Time'], hole=.3)])
            
    fig.update_traces(textposition='inside', textinfo='percent+label')
    
    fig.update_layout(
               title_text="Resolved Defect Id Frequency Distribution",
               showlegend=False,
               margin=dict(l=5, r=5, b=5, t=35, pad=2),

             # Add annotations in the center of the donut pies.
             annotations=[dict(text='Defect ID', x=0.5, y=0.5, font_size=12, showarrow=False)])
       
    return fig

@app.callback(Output(component_id='pie-chart2', component_property='figure'),
              [Input(component_id='col2', component_property='value')])

def pie_chart2(col0):

    if col0=='Defect Not Resolved':
        list1,list2 =[],[]
        dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==0]
        new = [(list1.append('{}'.format(i)),list2.append(j)) for i,j in zip(dy.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                        dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]
        defect_id_table = pd.DataFrame({"defect_id":list1,"freq_count":list2})
        defect_id_table['Avg_Time'] = (dy.groupby(['DEFECT_ID']).minutes.sum().values/dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)
        dataset = defect_id_table.copy()
        fig = go.Figure(data=[go.Pie(labels=dataset.defect_id, values=dataset['freq_count'], hole=.3)]) 
        
    if col0=='Average Time':
        list1,list2 =[],[]
        dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==0]
        new = [(list1.append('{}'.format(i)),list2.append(j)) for i,j in zip(dy.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                        dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]
        defect_id_table = pd.DataFrame({"defect_id":list1,"freq_count":list2})
        defect_id_table['Avg_Time'] = (dy.groupby(['DEFECT_ID']).minutes.sum().values/dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)
        dataset = defect_id_table.copy()
        
        fig = go.Figure(data=[go.Pie(labels=dataset.defect_id, values=dataset['Avg_Time'], hole=.3)])
            
    fig.update_traces(textposition='inside', textinfo='percent+label')
    
    fig.update_layout(
               title_text="Frequency Distribution of Unresolved Defects",
               showlegend=False,
               margin=dict(l=5, r=5, b=5, t=35, pad=2),

             # Add annotations in the center of the donut pies.
             annotations=[dict(text='Defect ID', x=0.5, y=0.5, font_size=12, showarrow=False)])
       
    return fig

@app.callback(Output(component_id='bar-plot', component_property='figure'),
              [Input(component_id='col3', component_property='value')])
def bar_plot(col1):
    #print(col1)
    try:

        if col1=='All':
             list3,list4 =[],[]
             new2 =[(list3.append(i),list4.append(j)) for i,j in zip(df.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                         df.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]

             year_defect = pd.DataFrame({"defect_id":list3,"freq_count":list4})
             data1 = pd.DataFrame({'defect_id':df.DEFECT_ID.value_counts().index,'freq_count':df.DEFECT_ID.value_counts().values})
             data1 = data1.sort_values('freq_count',ascending=False)


             fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                            text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                            freq_count="Frequency Distribution of Defect"),
                            title="Year wise Distributions of Defect Id")
        else:
             list3,list4,list5 =[],[],[]
             new2 =[(list3.append(i[0]),list4.append('{}'.format(i[1])),list5.append(j)) for i,j in zip(df.groupby(['year','DEFECT_ID']).DEFECT_ID.count().index,
                                                                                         df.groupby(['year','DEFECT_ID']).DEFECT_ID.count().values)]

             year_defect = pd.DataFrame({"year":list3,"defect_id":list4,"freq_count":list5})        
             data1 = year_defect[year_defect.year==int(col1)].copy()
             data1 = data1.sort_values('freq_count',ascending=False)
             fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                        text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                        freq_count="Frequency Distribution of Defect"),title="Year wise Distributions of Defect Id")


        fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False, showlegend=False,
                          margin=dict(l=5, r=5, b=5, t=35, pad=2))

        fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)

        # hiding color-bar 
        fig.update_coloraxes(showscale=False)

        return fig
    except:
            list3,list4 =[],[]
            new2 =[(list3.append(i),list4.append(j)) for i,j in zip(df.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                         df.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]

            year_defect = pd.DataFrame({"defect_id":list3,"freq_count":list4})
            data1 = pd.DataFrame({'defect_id':df.DEFECT_ID.value_counts().index,'freq_count':df.DEFECT_ID.value_counts().values})
            data1 = data1.sort_values('freq_count',ascending=False)
                 #lower = int(data1.shape[0]*float(slider_range[0]))
                 #upper = int(data1.shape[0]*float(slider_range[1]))
            fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                            text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                            freq_count="Frequency Distribution of Defect"),title="Year wise Distributions of Defect Id")


            fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                              autosize=False, showlegend=False,
                              margin=dict(l=5, r=5, b=5, t=35, pad=2))

            fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)

            # hiding color-bar 
            fig.update_coloraxes(showscale=False)

            return fig
#-----------------------------------------------------------#
@app.callback(Output(component_id='bar-plot1', component_property='figure'),
              [Input(component_id='col4', component_property='value')])
def bar_plot1(col1):
    #print(col1)
    try:
        if col1=='All':
             list3,list4,list5 =[],[],[]
             dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==1]
             new2 =[(list3.append(i),list4.append(j)) for i,j in zip(dy.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                             dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]

             year_defect = pd.DataFrame({"year":list3,"defect_id":list4,"freq_count":list5})
            
             data1 = pd.DataFrame({'defect_id':dy.DEFECT_ID.value_counts().index,'freq_count':dy.DEFECT_ID.value_counts().values})
             data1 = data1.sort_values('freq_count',ascending=False)

             fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                            text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                            freq_count="Frequency Distribution of Defect"),
                            title="Year wise Distributions of Resolved Defect Id")
        else:
             list3,list4,list5 =[],[],[]
             dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==1]
             new2 =[(list3.append(i[0]),list4.append('{}'.format(i[1])),list5.append(j)) for i,j in zip(dy.groupby(['year','DEFECT_ID']).DEFECT_ID.count().index,
                                                                                             dy.groupby(['year','DEFECT_ID']).DEFECT_ID.count().values)]

             year_defect = pd.DataFrame({"year":list3,"defect_id":list4,"freq_count":list5})
             data1 = year_defect[year_defect.year==int(col1)].copy()
             data1 = data1.sort_values('freq_count',ascending=False)
            
             fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                        text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                        freq_count="Frequency Distribution of Defect"),title="Year wise Distributions of Resolved Defect Id")


        fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False, showlegend=False,
                          margin=dict(l=5, r=5, b=5, t=35, pad=2))

        fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)

        # hiding color-bar 
        fig.update_coloraxes(showscale=False)

        return fig  
    
    except:
        list3,list4 =[],[]
        dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==1]
        new2 =[(list3.append(i),list4.append(j)) for i,j in zip(dy.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                             dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]

        year_defect = pd.DataFrame({"defect_id":list3,"freq_count":list3})
            
        data1 = pd.DataFrame({'defect_id':dy.DEFECT_ID.value_counts().index,'freq_count':dy.DEFECT_ID.value_counts().values})
        data1 = data1.sort_values('freq_count',ascending=False)


        fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                        text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                        freq_count="Frequency Distribution of Defect"),title="Year wise Distributions of Resolved Defects")


        fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False, showlegend=False,
                          margin=dict(l=5, r=5, b=5, t=35, pad=2))

        fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)

        # hiding color-bar 
        fig.update_coloraxes(showscale=False)

        return fig

#-----------------------------------------------------------#
@app.callback(Output(component_id='bar-plot2', component_property='figure'),
              [Input(component_id='col5', component_property='value')])
def bar_plot2(col1):
    #print(col1)
    try:
        if col1=='All':
             list3,list4,list5 =[],[],[]
             dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==0]
             new2 =[(list3.append(i),list4.append(j)) for i,j in zip(dy.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                             dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]

             year_defect = pd.DataFrame({"year":list3,"defect_id":list4,"freq_count":list5})
            
             data1 = pd.DataFrame({'defect_id':dy.DEFECT_ID.value_counts().index,'freq_count':dy.DEFECT_ID.value_counts().values})
             data1 = data1.sort_values('freq_count',ascending=False)

             fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                            text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                            freq_count="Frequency Distribution of Defect"),
                            title="Year wise Distributions of Unresolved Defects")
        else:
             list3,list4,list5 =[],[],[]
             dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==0]
             new2 =[(list3.append(i[0]),list4.append('{}'.format(i[1])),list5.append(j)) for i,j in zip(dy.groupby(['year','DEFECT_ID']).DEFECT_ID.count().index,
                                                                                             dy.groupby(['year','DEFECT_ID']).DEFECT_ID.count().values)]

             year_defect = pd.DataFrame({"year":list3,"defect_id":list4,"freq_count":list5})
             data1 = year_defect[year_defect.year==int(col1)].copy()
             data1 = data1.sort_values('freq_count',ascending=False)
            
             fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                        text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                        freq_count="Frequency Distribution of Defect"),title="Year wise Distributions of Unresolved Defects")


        fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False, showlegend=False,
                          margin=dict(l=5, r=5, b=5, t=35, pad=2))

        fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)

        # hiding color-bar 
        fig.update_coloraxes(showscale=False)

        return fig  
    
    except:
        list3,list4 =[],[]
        dy = df[df.ASSEMBLY_DEFECT_IS_RESOLVED==0]
        new2 =[(list3.append(i),list4.append(j)) for i,j in zip(dy.groupby(['DEFECT_ID']).DEFECT_ID.count().index,
                                                                                             dy.groupby(['DEFECT_ID']).DEFECT_ID.count().values)]

        year_defect = pd.DataFrame({"defect_id":list3,"freq_count":list4})
            
        data1 = pd.DataFrame({'defect_id':dy.DEFECT_ID.value_counts().index,'freq_count':dy.DEFECT_ID.value_counts().values})
        data1 = data1.sort_values('freq_count',ascending=False)


        fig = px.bar(data1, y="defect_id", x="freq_count", color="defect_id",orientation='h',
                        text_auto=True, labels=dict(defect_id="Defect IDs on X-axis",
                        freq_count="Frequency Distribution of Defect"),title="Year wise Distributions of Unresolved Defects")


        fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False, showlegend=False,
                          margin=dict(l=5, r=5, b=5, t=35, pad=2))

        fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)

        # hiding color-bar 
        fig.update_coloraxes(showscale=False)

        return fig
    
#-----------------------------------------------------------#
@app.callback(Output(component_id='bar-plot3', component_property='figure'),
              [Input(component_id='col6', component_property='value')])
def bar_plot3(col1):
        #print(col1)
        list6,list7,list8 =[],[],[]

        new3 =[(list6.append(i[0]),list7.append(i[1]),list8.append(j)) for i,j in zip(df.groupby(['DEFECT_ID','STATION_ID_NAME']).STATION_ID.count().index,
                                                                                               df.groupby(['DEFECT_ID','STATION_ID_NAME']).STATION_ID.count().values)]

        year_month = pd.DataFrame({"DEFECT_ID":list6,"STATION_ID_NAME":list7,"freq_count":list8})

        year_month = year_month.sort_values('freq_count',ascending =False)

        data1 = year_month[year_month.STATION_ID_NAME==col1].copy()
        #print(data1)
        fig = px.bar(data1, y="DEFECT_ID", x="freq_count", color="DEFECT_ID",orientation='h',
                        text_auto=True, labels=dict(DEFECT_ID="Defect IDs on X-axis",freq_count="Frequency Distribution of Defect"),
                        title="Station Based Defect Distributions")


        fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False, showlegend=False,
                          margin=dict(l=5, r=5, b=5, t=35, pad=2))

        fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)

        # hiding color-bar 
        fig.update_coloraxes(showscale=False)

        return fig    

#-----------------------------------------------------------#
@app.callback(Output(component_id='bar-plot4', component_property='figure'),
              [Input(component_id='col7', component_property='value')])
def bar_plot4(col1):
     list9,list10,list11,list12=[],[],[],[]
     new2 = [(list9.append(i[0]),list10.append(i[1]),list11.append(i[2]),list12.append(j)) for i,j in zip(df.groupby(['STATION_ID_NAME','DEFECT_ID','DEFECT_CATEGORY_ID']).DEFECT_CATEGORY_ID.count().index,
                                                                            df.groupby(['STATION_ID_NAME','DEFECT_ID','DEFECT_CATEGORY_ID']).DEFECT_CATEGORY_ID.count().values)]
    
     dataset = pd.DataFrame({"STATION_ID_NAME":list9,"DEFECT_ID":list10,"DEFECT_CATEGORY_ID":list11,"freq_count":list12})
        
     dataset = dataset[dataset.STATION_ID_NAME==col1].copy()
    
     fig = px.bar(dataset, y="DEFECT_CATEGORY_ID", x="freq_count", color="DEFECT_ID",orientation='h',
                                text_auto=True, labels=dict(DEFECT_CATEGORY_ID="DEFECT Sub-CATEGORY distributions",
                                freq_count="Frequency Distribution"),title="Defect Sub-Category distribution by Work-Station")
     
     fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)
        
     fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False,# showlegend=True,
                          margin=dict(l=5, r=5, b=5, t=30, pad=2))
    
     fig.update_layout(legend=dict(orientation="h",
     #yanchor="bottom",
     y=-0.20,
     #xanchor="right",
     #x=1
     ))
    
     # hiding color-bar 
     fig.update_coloraxes(showscale=False)

     return fig 

#-----------------------------------------------------------#
@app.callback(Output(component_id='bar-plot5', component_property='figure'),
              [Input(component_id='col8', component_property='value'),
              Input(component_id='col9', component_property='value')])
def bar_plot5(col1,col2):
    list1,list2,list3,list4 =[],[],[],[]
    new = [(list1.append(i[0]),list2.append(i[1]),list3.append(i[2]),list4.append(j)) 
               for i,j in zip(df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).OPERATOR_LOGIN_NAME.count().index,
                              df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).OPERATOR_LOGIN_NAME.count().values)]

    data = pd.DataFrame({"SKILL_NAME":list1,"STATION_ID_NAME":list2,"OPERATOR_LOGIN_NAME":list3,"freq_count":list4})
    data['Minutes'] = [f for f in df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).minutes.sum().values]
    data['Seconds'] = [f for f in df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).Seconds.sum().values]
    data['Hours']   = [f for f in df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).hours.sum().values]
    data['Avg_Time']= [f for f in (df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).minutes.sum()/
                                df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).OPERATOR_LOGIN_NAME.count()).values]
    dataset = data[(data.STATION_ID_NAME=='{}'.format(col1))].copy()
    #print(dataset)

    if col2=='Avg_Time':
        fig = px.bar(dataset, x="OPERATOR_LOGIN_NAME", y="Avg_Time", color="SKILL_NAME",
                                text_auto=True, labels=dict(OPERATOR_LOGIN_NAME="Operator Name on X-axis",
                                Avg_Time="Time in Minutes"),title="Station wise Operator's Stats")

    if col2=='Count':
        fig = px.bar(dataset, x="OPERATOR_LOGIN_NAME", y="freq_count", color="SKILL_NAME",
                                text_auto=True, labels=dict(OPERATOR_LOGIN_NAME="Operator Name on X-axis",
                                freq_count="Frequency Distribution"),title="Operator created Assembly count")
     
    fig.update_traces(textfont_size=10, textangle=0, textposition="outside", cliponaxis=False)
    fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False,# showlegend=True,
                          margin=dict(l=5, r=5, b=5, t=30, pad=2))
    fig.update_layout(legend=dict(
    orientation="h",
    #yanchor="bottom",
    y=-0.80,
    #xanchor="right",
    #x=1
    ))
    
    # hiding color-bar 
    fig.update_coloraxes(showscale=False)

    return fig 

@app.callback(Output(component_id='bar-plot6', component_property='figure'),
              [Input(component_id='col10', component_property='value'),
              Input(component_id='col11', component_property='value')])
def bar_plot6(col1,col2):

        list1,list2,list3,list4 =[],[],[],[]
        new = [(list1.append(i[0]),list2.append(i[1]),list3.append(i[2]),list4.append(j)) 
               for i,j in zip(df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).OPERATOR_LOGIN_NAME.count().index,
                              df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).OPERATOR_LOGIN_NAME.count().values)]

        data = pd.DataFrame({"SKILL_NAME":list1,"STATION_ID_NAME":list2,"OPERATOR_LOGIN_NAME":list3,"freq_count":list4})
        data['Minutes'] = [f for f in df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).minutes.sum().values]
        data['Seconds'] = [f for f in df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).Seconds.sum().values]
        data['Hours']   = [f for f in df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).hours.sum().values]
        data['Avg_Time']=[f for f in (df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).minutes.sum().values/
                                      df.groupby(['SKILL_NAME','STATION_ID_NAME','OPERATOR_LOGIN_NAME']).OPERATOR_LOGIN_NAME.count().values)]
        
        dataset = data[(data.SKILL_NAME=='{}'.format(col1))].copy()
        #print(dataset)
       
        if col2=='Avg_Time':

           fig = px.bar(dataset, x="OPERATOR_LOGIN_NAME", y='Avg_Time', color="STATION_ID_NAME",
                        text_auto=True,hover_data=dataset.columns, labels=dict(OPERATOR_LOGIN_NAME="OPERATOR_LOGIN_NAME on X-axis",
                        Avg_Time="Time Distribution"),title="Skill Based Operator's Time Distribution")
        
        if col2=="Count":
           dataset = dataset.sort_values('freq_count',ascending=False)
           #print(dataset)
           fig = px.bar(dataset, x="OPERATOR_LOGIN_NAME", y="freq_count", color='STATION_ID_NAME',
                        text_auto=True,hover_data=dataset.columns, labels=dict(OPERATOR_LOGIN_NAME="OPERATOR_LOGIN_NAME on X-axis",
                        freq_count="Frequency Distribution"),title="Skill Based Operator's Time Distribution")

        fig.update_traces(textfont_size=10, textangle=0, textposition="auto", cliponaxis=False)
        fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False,# showlegend=True,
                          margin=dict(l=5, r=5, b=5, t=30, pad=2))
        
        fig.update_layout(legend=dict(
        orientation="h",
        #yanchor="bottom",
        y=-0.80,
        #xanchor="right",
        #x=1
        ))
        return fig
    
@app.callback(Output(component_id='bar-plot7', component_property='figure'),
              [Input(component_id='col12', component_property='value'),
              Input(component_id='col13', component_property='value')])
def bar_chart7(col1,col2):
    #print(col1,col2)    
    
    if col1=='All':
        list1,list2,list3=[],[],[]
        new1 = [(list1.append(i),list2.append(i[1]),list3.append(j)) for i,j in zip(df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['MECHANICAL_STATION_ID','STATION_ID_NAME']).MECHANICAL_STATION_ID.count().index,
                                                                 df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['MECHANICAL_STATION_ID','STATION_ID_NAME']).MECHANICAL_STATION_ID.count().values)]

        data1 = pd.DataFrame({'MECHANICAL_STATION_ID':list1,'STATION_ID_NAME':list2,'freq_count':list3})
        data1['Minutes'] = [f for f in df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['MECHANICAL_STATION_ID']).minutes.sum().values]
        data1['Seconds'] = [f for f in df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['MECHANICAL_STATION_ID']).Seconds.sum().values]
        data1['Hours']   = [f for f in df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['MECHANICAL_STATION_ID']).hours.sum().values]
        data1['Avg_Time']= [f for f in (df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['MECHANICAL_STATION_ID']).minutes.sum().values/df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['MECHANICAL_STATION_ID']).MECHANICAL_STATION_ID.count().values)]
        dataset = data1.copy()
    
    else:
        list4,list5,list6,list7 =[],[],[],[]
        new2 = [(list4.append(i[0]),list5.append(i[1]),list6.append(i[2]),list7.append(j)) for i ,j in zip(df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['year','MECHANICAL_STATION_ID','STATION_ID_NAME']).MECHANICAL_STATION_ID.count().index,
                                                                                             df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['year','MECHANICAL_STATION_ID','STATION_ID_NAME']).MECHANICAL_STATION_ID.count().values)]
        data1 = pd.DataFrame({"year":list4,"MECHANICAL_STATION_ID":list5,"STATION_ID_NAME":list6,"freq_count":list7})
        data1['Minutes'] = [f for f in df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['year','MECHANICAL_STATION_ID','STATION_ID_NAME']).minutes.sum().values]
        data1['Hours']   = [f for f in df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['year','MECHANICAL_STATION_ID','STATION_ID_NAME']).hours.sum().values]
        data1['Seconds'] = [f for f in df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['year','MECHANICAL_STATION_ID','STATION_ID_NAME']).Seconds.sum().values]
        data1['Avg_Time']= [f for f in (df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['year','MECHANICAL_STATION_ID','STATION_ID_NAME']).minutes.sum().values/
                                        df[(df.MECHANICAL_STICKER_STATUS==1)].groupby(['year','MECHANICAL_STATION_ID','STATION_ID_NAME']).MECHANICAL_STATION_ID.count().values)]

        dataset = data1[data1.year==int(col1)].copy() 
        
    if col2=='Count': 
        dataset = dataset.sort_values('freq_count',ascending=False)
        fig = px.bar(dataset, x="STATION_ID_NAME", y="freq_count", color="STATION_ID_NAME",
                                        text_auto=True, labels=dict(OPERATOR_LOGIN_NAME="Station ID on X-axis",
                                        freq_count="Frequency Distribution"),
                                        title="Mechanical Sticker Assigned", orientation='v')
                
    if col2=='Avg_Time':
        dataset = dataset.sort_values('Avg_Time',ascending=False)
        fig = px.bar(dataset, x="STATION_ID_NAME", y="Avg_Time", color="STATION_ID_NAME",
                                        text_auto=True, labels=dict(STATION_ID_NAME="Operator Name on X-axis",
                                        Avg_Time="Time in minutes"),
                                        title="Mechanical Sticker Assigned", orientation='v')
        
    fig.update_traces(textfont_size=10, textangle=0, textposition="outside", cliponaxis=False)
    
    fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                              autosize=False, showlegend=False,
                              margin=dict(l=5, r=5, b=5, t=30, pad=2)) 
    
    # hiding color-bar 
    fig.update_coloraxes(showscale=False)
    return fig
@app.callback(Output(component_id='bar-plot8', component_property='figure'),
              [Input(component_id='col14', component_property='value'),
               Input(component_id='col15', component_property='value')])
def bar_chart8(col1,col2):
    #print(col1)
    list6,list7,list8,list9,list10 =[],[],[],[],[] 
    list11,list12,list13,list14,list15,list16 =[],[],[],[],[],[]
    dp = df[df.SERIAL_NUMBER.isin(np.unique(df[(df.MECHANICAL_STICKER_STATUS==1)].SERIAL_NUMBER.value_counts().index))].copy()
    new1 = [(list6.append(i[0]),list7.append(i[1]),list8.append(i[2]),list9.append(i[3]),list10.append(j)) for i,j in zip(dp[dp.PRODUCTION_PLAN_CUSTOMER=='{}'.format(col1)].groupby(['PRODUCTION_PLAN_CUSTOMER','PRODUCTION_PLAN_QUANTITY','SERIAL_NUMBER','SALE_ORDER_NUMBER']).minutes.sum().index,
                                                                          dp[dp.PRODUCTION_PLAN_CUSTOMER=='{}'.format(col1)].groupby(['PRODUCTION_PLAN_CUSTOMER','PRODUCTION_PLAN_QUANTITY','SERIAL_NUMBER','SALE_ORDER_NUMBER']).minutes.sum().values)]
    
    results = pd.DataFrame({"PRODUCTION_PLAN_CUSTOMER":list6,'PRODUCTION_PLAN_QUANTITY':list7,'SERIAL_NUMBER':list8,
                           'SALE_ORDER_NUMBER':list9,'Minutes':list10})
    if col2=='mean':
       target = results.Minutes.mean()
    if col2=='median':
       target = results.Minutes.median() 
    for i in df[df.PRODUCTION_PLAN_CUSTOMER=='{}'.format(col1)].groupby(['SERIAL_NUMBER']).minutes.sum().index:
        if i not in dp[dp.PRODUCTION_PLAN_CUSTOMER=='{}'.format(col1)].groupby(['SERIAL_NUMBER']).minutes.sum().index:
            sr_no = i
            #print(i)
            #a1 = df[df.SERIAL_NUMBER=='{}'.format(sr_no)].minutes.sum() * -1
            #a2 = df[df.SERIAL_NUMBER=='{}'.format(sr_no)].iloc[-1:,:].PRODUCTION_PLAN_CUSTOMER.values
            #a3 = df[df.SERIAL_NUMBER=='{}'.format(sr_no)].iloc[-1:,:].PRODUCTION_PLAN_QUANTITY.values
            #a4 = df[df.SERIAL_NUMBER=='{}'.format(sr_no)].iloc[-1:,:].SERIAL_NUMBER.values
            #a5 = df[df.SERIAL_NUMBER=='{}'.format(sr_no)].iloc[-1:,:].SALE_ORDER_NUMBER.values
            
            list11.append(df[df.SERIAL_NUMBER=='{}'.format(sr_no)].minutes.sum())
            list12.append(df[df.SERIAL_NUMBER=='{}'.format(sr_no)].iloc[-1:,:].PRODUCTION_PLAN_CUSTOMER.values[0])
            list13.append(df[df.SERIAL_NUMBER=='{}'.format(sr_no)].iloc[-1:,:].PRODUCTION_PLAN_QUANTITY.values[0])
            list14.append(df[df.SERIAL_NUMBER=='{}'.format(sr_no)].iloc[-1:,:].SERIAL_NUMBER.values[0])
            list15.append(df[df.SERIAL_NUMBER=='{}'.format(sr_no)].iloc[-1:,:].SALE_ORDER_NUMBER.values[0])
            list16.append('No')
        else:
            list16.append('Yes')
           
    result1= pd.DataFrame({"PRODUCTION_PLAN_CUSTOMER":list12,'PRODUCTION_PLAN_QUANTITY':list12,'SERIAL_NUMBER':list14,
                               'SALE_ORDER_NUMBER':list15,'Minutes':list11})

    
    results = results.append(result1)
    results['MECHANICAL_STICKER_STATUS']=list16
    #print(results)
    features =["PRODUCTION_PLAN_CUSTOMER",'PRODUCTION_PLAN_QUANTITY','SERIAL_NUMBER','SALE_ORDER_NUMBER','Minutes','MECHANICAL_STICKER_STATUS']

    results = results.sort_values('SERIAL_NUMBER',ascending=True)

    dataset = results[features].copy() #dataset.sort_values('Avg_Time',ascending=False)
    #print(dataset)
    fig = px.bar(dataset, x="SERIAL_NUMBER", y="Minutes", color="MECHANICAL_STICKER_STATUS",hover_data=dataset.columns,
                                text_auto='.2s', labels=dict(SERIAL_NUMBER="SERIAL_NUMBER on X-axis",
                                Minutes="Time required in minutes"),title="Product Time Distribution")
    fig.add_hline(y=target,line_width=2, line_dash="dash", line_color="black") 
    fig.update_traces(textfont_size=10, textangle=0, textposition="outside", cliponaxis=False)
    fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False,# showlegend=True,
                          margin=dict(l=5, r=5, b=5, t=30, pad=2))
    fig.update_layout(legend=dict(
    orientation="h",
    #yanchor="bottom",
    y=-0.80,
    #xanchor="right",
    #x=1
    ))
    
    # hiding color-bar 
    fig.update_coloraxes(showscale=False)

    return fig

@app.callback(Output(component_id='bar-plot9', component_property='figure'),
              [Input(component_id='col16', component_property='value'),
               Input(component_id='col17', component_property='value')])
def bar_chart9(col1,col2):
#df[df.PRODUCTION_PLAN_CUSTOMER=='ABB Power Products _ HRRL - Construction Power'].groupby(['SERIAL_NUMBER','DEFECT_ID','STATION_ID']).minutes.sum()    
    data1 = df[df.PRODUCTION_PLAN_CUSTOMER=='{}'.format(col1)].copy()
    list1,list2,list3,list4,list5 =[],[],[],[],[]
    
    new1 = [(list1.append(i[0]),list2.append(i[1]),list3.append(i[2]),list4.append(j)) for i,j in zip(data1.groupby(['SERIAL_NUMBER','DEFECT_ID','STATION_ID_NAME']).minutes.sum().index,
                                                                                                     data1.groupby(['SERIAL_NUMBER','DEFECT_ID','STATION_ID_NAME']).minutes.sum().values)]
    
    dataset = pd.DataFrame({"SERIAL_NUMBER":list1,"DEFECT_ID":list2,"STATION_ID_NAME":list3,"Minutes":list4})
    if col2=='mean':
       target = dataset.Minutes.mean()
    if col2=='median':
       target = dataset.Minutes.median()
    
    fig = px.bar(dataset, x="SERIAL_NUMBER", y="Minutes", color="DEFECT_ID",hover_data=dataset.columns,
                                text_auto='.2s', labels=dict(SERIAL_NUMBER="SERIAL_NUMBER on X-axis",
                                Minutes="Time required in minutes"),title="Product Time Distribution by Defects")
    fig.add_hline(y=target,line_width=2, line_dash="dash", line_color="black") 
    fig.update_traces(textfont_size=10, textangle=0, textposition="outside", cliponaxis=False)
    fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide',xaxis_tickangle=-90,
                          autosize=False,# showlegend=True,
                          margin=dict(l=5, r=5, b=5, t=30, pad=2))
    fig.update_layout(legend=dict(
    orientation="h",
    #yanchor="bottom",
    y=-0.80,
    #xanchor="right",
    #x=1
    ))
    
    # hiding color-bar 
    fig.update_coloraxes(showscale=False)

    return fig

app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Feb/2023 13:13:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Feb/2023 13:13:46] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Feb/2023 13:13:46] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Feb/2023 13:13:46] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Feb/2023 13:13:46] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Feb/2023 13:13:46] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Feb/2023 13:13:47] "POST /_dash-update-component HTTP/1.1" 200 -
# ...
